# %%
import pandas as pd
from Edmonds_Karp_algo import run_edmond_karp_algo
import matplotlib.pyplot as plt
path = r"../../Graph/Graphs_edges.csv"
df = pd.read_csv(path)

maxflow,residual,history=run_edmond_karp_algo(df,source='s',sink='t',verbose=False)

plt.figure(figsize=(6,4))
plt.plot(history)
plt.title("Convergence of Bat (paths-based) for Max Flow")
plt.xlabel("Iteration")
plt.ylabel("Best total flow found")
plt.grid(True)
plt.show()
