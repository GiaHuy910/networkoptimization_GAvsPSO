# %%
from ga_op import CompleteMaxFlowGA
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv(r"../../Graph/Graphs_edges.csv")
ga = CompleteMaxFlowGA()
all_paths_with_flows, best_flow_value,generation_history,history = ga.run_complete_max_flow_ga(df,'s','t'
                            ,population_size=30, max_generations=300
                            ,mutation_rate=0.2, crossover_rate=0.8
                            ,verbose=False)
print(all_paths_with_flows)
print(best_flow_value)
print(generation_history)
print(history)
plt.figure(figsize=(6,4))
plt.plot(history)
plt.title("Convergence of Bat (paths-based) for Max Flow")
plt.xlabel("Iteration")
plt.ylabel("Best total flow found")
plt.grid(True)
plt.show()
# Out:
# [{'path': [4, 2, 1, 5], 'path_names': ['s', '4', '3', 't'], 'flow': np.float64(2.975640700622697), 'path_string': 's -> 4 -> 3 -> t'}, {'path': [4, 0, 1, 5], 'path_names': ['s', '2', '3', 't'], 'flow': np.float64(2.845457691142106), 'path_string': 's -> 2 -> 3 -> t'}, {'path': [4, 0, 3, 5], 'path_names': ['s', '2', '5', 't'], 'flow': np.float64(2.1359677744864562), 'path_string': 's -> 2 -> 5 -> t'}, {'path': [4, 2, 3, 5], 'path_names': ['s', '4', '5', 't'], 'flow': 0.9991700695476233, 'path_string': 's -> 4 -> 5 -> t'}]
# 8.956236235798883
# ...
